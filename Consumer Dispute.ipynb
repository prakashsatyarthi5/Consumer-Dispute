# %% [markdown]
# ###### The Consumer Financial Protection Bureau (CFPB) is a federal U.S. agency that acts as a mediator when disputes arise between financial institutions and consumers. Via a web form, consumers can send the agency a narrative of their dispute.

# %% [markdown]
# ###### This project made using Natural Language Processing (NLP) with machine learning models to process the issues text written in the complaint and other features in the dataset to predict if the customer will dispute or not.

# %% [markdown]
# ###### Industry use case: An NLP + Machine learning model would make the classification of whether the consumer will dispute with the companty or not and thus helping the company to prioritize the complaint based on the prediction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

pd.set_option("display.max_columns", 50)

# %%
df=pd.read_csv('complaints.csv')

# %%
df.sample(5)
# Out:
#         Date received                                            Product  \
# 1758277    2023-05-25  Credit reporting, credit repair services, or o...
# 3354625    2024-02-18  Credit reporting or other personal consumer re...
# 4722910    2024-04-16  Credit reporting or other personal consumer re...
# 1400104    2024-02-20  Credit reporting or other personal consumer re...
# 1611666    2024-03-15  Credit reporting or other personal consumer re...
#
#               Sub-product                                              Issue  \
# 1758277  Credit reporting               Incorrect information on your report
# 3354625  Credit reporting                        Improper use of your report
# 4722910  Credit reporting  Problem with a company's investigation into an...
# 1400104  Credit reporting                        Improper use of your report
# 1611666  Credit reporting               Incorrect information on your report
#
#                                              Sub-issue  \
# 1758277            Information belongs to someone else
# 3354625  Reporting company used your report improperly
# 4722910     Problem with personal statement of dispute
# 1400104  Reporting company used your report improperly
# 1611666            Information belongs to someone else
#
#                               Consumer complaint narrative  \
# 1758277  I am writing to dispute the following accounts...
# 3354625  According to the Fair Credit Reporting Act 15 ...
# 4722910                                                NaN
# 1400104                                                NaN
# 1611666                                                NaN
#
#                                    Company public response  \
# 1758277  Company has responded to the consumer and the ...
# 3354625  Company has responded to the consumer and the ...
# 4722910                                                NaN
# 1400104                                                NaN
# 1611666                                                NaN
#
#                                         Company State ZIP code Tags  \
# 1758277     Experian Information Solutions Inc.    CA    93638  NaN
# 3354625  TRANSUNION INTERMEDIATE HOLDINGS, INC.    CA    90018  NaN
# 4722910                           EQUIFAX, INC.    FL    33545  NaN
# 1400104                              LEXISNEXIS    IL    60411  NaN
# 1611666                           EQUIFAX, INC.    TX    77545  NaN
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 1758277           Consent provided           Web           2023-05-25
# 3354625           Consent provided           Web           2024-02-18
# 4722910       Consent not provided           Web           2024-04-16
# 1400104       Consent not provided           Web           2024-02-20
# 1611666       Consent not provided           Web           2024-03-15
#
#             Company response to consumer Timely response? Consumer disputed?  \
# 1758277          Closed with explanation              Yes                NaN
# 3354625  Closed with non-monetary relief              Yes                NaN
# 4722910  Closed with non-monetary relief              Yes                NaN
# 1400104  Closed with non-monetary relief              Yes                NaN
# 1611666  Closed with non-monetary relief              Yes                NaN
#
#          Complaint ID
# 1758277       7030559
# 3354625       8367896
# 4722910       8784799
# 1400104       8382984
# 1611666       8548497

# %%
round(df['Consumer disputed?'].value_counts(normalize=True)*100)
# Out:
# Consumer disputed?
# No     81.0
# Yes    19.0
# Name: proportion, dtype: float64

# %%
df['Consumer complaint narrative'].replace('NaN', np.nan, inplace=True)

# %%
df.sample(5)
# Out:
#         Date received                                            Product  \
# 4858387    2012-02-10                                           Mortgage
# 2654106    2023-03-04  Credit reporting, credit repair services, or o...
# 4355824    2024-05-20  Credit reporting or other personal consumer re...
# 2976059    2022-03-06                        Checking or savings account
# 3780397    2021-06-08  Credit reporting, credit repair services, or o...
#
#               Sub-product                                     Issue  \
# 4858387   Second mortgage  Loan modification,collection,foreclosure
# 2654106  Credit reporting      Incorrect information on your report
# 4355824  Credit reporting      Incorrect information on your report
# 2976059  Checking account                       Managing an account
# 3780397  Credit reporting      Incorrect information on your report
#
#                                    Sub-issue  \
# 4858387                                  NaN
# 2654106  Information belongs to someone else
# 4355824  Information belongs to someone else
# 2976059                       Banking errors
# 3780397  Information belongs to someone else
#
#                               Consumer complaint narrative  \
# 4858387                                                NaN
# 2654106                                                NaN
# 4355824                                                NaN
# 2976059  On XX/XX/XXXX I applied and was approved for a...
# 3780397                                                NaN
#
#                                    Company public response  \
# 4858387                                                NaN
# 2654106  Company has responded to the consumer and the ...
# 4355824                                                NaN
# 2976059  Company has responded to the consumer and the ...
# 3780397                                                NaN
#
#                                         Company State ZIP code Tags  \
# 4858387   BANK OF AMERICA, NATIONAL ASSOCIATION    CA    91411  NaN
# 2654106  TRANSUNION INTERMEDIATE HOLDINGS, INC.    GA    30035  NaN
# 4355824                           EQUIFAX, INC.    FL    33178  NaN
# 2976059                          CITIBANK, N.A.    KY    41051  NaN
# 3780397                           EQUIFAX, INC.    NY    11239  NaN
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 4858387                        NaN      Referral           2012-02-10
# 2654106       Consent not provided           Web           2023-03-04
# 4355824                        NaN           Web           2024-05-20
# 2976059           Consent provided           Web           2022-03-06
# 3780397       Consent not provided           Web           2021-06-08
#
#             Company response to consumer Timely response? Consumer disputed?  \
# 4858387            Closed without relief               No                 No
# 2654106  Closed with non-monetary relief              Yes                NaN
# 4355824                      In progress              Yes                NaN
# 2976059      Closed with monetary relief              Yes                NaN
# 3780397          Closed with explanation              Yes                NaN
#
#          Complaint ID
# 4858387         22595
# 2654106       6649196
# 4355824       9051865
# 2976059       5290832
# 3780397       4441921

# %%
df.fillna('', inplace=True)

# %%
df.sample(5)
# Out:
#         Date received                                            Product  \
# 3722235    2021-07-15  Credit reporting, credit repair services, or o...
# 5278640    2024-03-19  Credit reporting or other personal consumer re...
# 4798715    2017-01-22                                       Student loan
# 4454330    2020-05-07                        Checking or savings account
# 1269732    2023-07-25  Credit reporting, credit repair services, or o...
#
#                       Sub-product  \
# 3722235          Credit reporting
# 5278640          Credit reporting
# 4798715  Non-federal student loan
# 4454330          Checking account
# 1269732          Credit reporting
#
#                                                      Issue  \
# 3722235  Problem with a credit reporting company's inve...
# 5278640               Incorrect information on your report
# 4798715                 Dealing with my lender or servicer
# 4454330                                Managing an account
# 1269732  Problem with a credit reporting company's inve...
#
#                                                  Sub-issue  \
# 3722235  Was not notified of investigation status or re...
# 5278640                Information belongs to someone else
# 4798715              Trouble with how payments are handled
# 4454330                           Deposits and withdrawals
# 1269732  Their investigation did not fix an error on yo...
#
#                               Consumer complaint narrative  \
# 3722235  These accounts are not mine. According to XXXX...
# 5278640
# 4798715  I have been with Sallie Mae since XX/XX/XXXX w...
# 4454330
# 1269732  I have previously disputed XXXX XXXX Bankruptc...
#
#                                    Company public response  \
# 3722235
# 5278640
# 4798715  Company believes it acted appropriately as aut...
# 4454330
# 1269732  Company has responded to the consumer and the ...
#
#                                      Company State ZIP code           Tags  \
# 3722235                        EQUIFAX, INC.    FL    34786
# 5278640                        EQUIFAX, INC.    FL    33805  Servicemember
# 4798715                      SLM CORPORATION    MO    64119
# 4454330                 JPMORGAN CHASE & CO.    NY    10031
# 1269732  Experian Information Solutions Inc.    MI    48197
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 3722235           Consent provided           Web           2021-07-15
# 5278640       Consent not provided           Web           2024-03-19
# 4798715           Consent provided           Web           2017-01-22
# 4454330                                 Referral           2020-05-07
# 1269732           Consent provided           Web           2023-07-25
#
#             Company response to consumer Timely response? Consumer disputed?  \
# 3722235          Closed with explanation              Yes
# 5278640  Closed with non-monetary relief              Yes
# 4798715      Closed with monetary relief              Yes                 No
# 4454330          Closed with explanation              Yes
# 1269732          Closed with explanation              Yes
#
#          Complaint ID
# 3722235       4546018
# 5278640       8583424
# 4798715       2302991
# 4454330       3641729
# 1269732       7294815

# %%
df.replace('', np.nan, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5479762 entries, 0 to 5479761
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# dtypes: int64(1), object(17)
# memory usage: 752.5+ MB

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

print('We have {} numerical features: {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features: {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 1 numerical features: ['Complaint ID']
#
# We have 17 categorical features: ['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'Consumer complaint narrative', 'Company public response', 'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?', 'Submitted via', 'Date sent to company', 'Company response to consumer', 'Timely response?', 'Consumer disputed?']

# %%
missing=df.isnull().sum().div(df.shape[0]).mul(100).to_frame().sort_values(by=0, ascending=True)
missing
# Out:
#                                       0
# Date received                  0.000000
# Timely response?               0.000000
# Date sent to company           0.000000
# Submitted via                  0.000000
# Company                        0.000000
# Complaint ID                   0.000000
# Product                        0.000000
# Issue                          0.000109
# Company response to consumer   0.000292
# ZIP code                       0.551593
# State                          0.843960
# Sub-product                    4.293891
# Sub-issue                     13.494856
# Consumer consent provided?    19.467926
# Company public response       51.788910
# Consumer complaint narrative  65.134927
# Consumer disputed?            85.979026
# Tags                          90.962454

# %%
# Define a dictionary with the proportion of NaN values
nan_proportions = {
    'Issue': 0.000109,
    'Company response to consumer': 0.000292,
    'ZIP code': 0.551593,
    'State': 0.843960,
    'Sub-product': 4.293891,
    'Sub-issue': 13.494856,
    'Consumer consent provided?': 19.467926,
    'Company public response': 51.788910,
    'Consumer complaint narrative': 65.134927,
    'Consumer disputed?': 85.979026,
    'Tags': 90.962454
}

# %%
for column, proportion in nan_proportions.items():
    if proportion < 5:
        df[column].fillna('Unknown', inplace=True)
    elif proportion < 50:
        if df[column].dtype == 'O':
            df[column].fillna(df[column].mode()[0], inplace=True)
        else:
            df[column].fillna(df[column].mean(), inplace=True)
    else:
        df.drop(columns=[column], inplace=True)

print("\nDataFrame after handling NaN values based on specific proportions:")
print(df)
# Out:
# DataFrame after handling NaN values based on specific proportions:
#         Date received                                            Product  \
# 0          2024-06-19  Credit reporting or other personal consumer re...
# 1          2024-06-19  Credit reporting or other personal consumer re...
# 2          2024-06-19  Credit reporting or other personal consumer re...
# 3          2024-06-19  Credit reporting or other personal consumer re...
# 4          2024-06-16                          Debt or credit management
# ...               ...                                                ...
# 5479757    2013-06-04                                        Credit card
# 5479758    2011-12-30                                        Credit card
# 5479759    2013-04-23                                           Mortgage
# 5479760    2013-03-05                                           Mortgage
# 5479761    2012-05-01                                        Credit card
#
#                          Sub-product  \
# 0                   Credit reporting
# 1                   Credit reporting
# 2                   Credit reporting
# 3                   Credit reporting
# 4                    Debt settlement
# ...                              ...
# 5479757                      Unknown
# 5479758                      Unknown
# 5479759               Other mortgage
# 5479760  Conventional fixed mortgage
# 5479761                      Unknown
#
#                                             Issue  \
# 0                     Improper use of your report
# 1            Incorrect information on your report
# 2                     Improper use of your report
# 3                     Improper use of your report
# 4                Confusing or missing disclosures
# ...                                           ...
# 5479757                          Billing disputes
# 5479758     Identity theft / Fraud / Embezzlement
# 5479759  Loan servicing, payments, escrow account
# 5479760  Application, originator, mortgage broker
# 5479761                                   Privacy
#
#                                                  Sub-issue  \
# 0            Reporting company used your report improperly
# 1                      Information belongs to someone else
# 2        Credit inquiries on your report that you don't...
# 3        Credit inquiries on your report that you don't...
# 4                      Information belongs to someone else
# ...                                                    ...
# 5479757                Information belongs to someone else
# 5479758                Information belongs to someone else
# 5479759                Information belongs to someone else
# 5479760                Information belongs to someone else
# 5479761                Information belongs to someone else
#
#                                         Company State ZIP code  \
# 0        TRANSUNION INTERMEDIATE HOLDINGS, INC.    CO    80249
# 1                                 EQUIFAX, INC.    FL    33311
# 2                                 EQUIFAX, INC.    AZ    85641
# 3                                 EQUIFAX, INC.    MA    02155
# 4                        Blitt and Gaines, P.C.    AZ    85353
# ...                                         ...   ...      ...
# 5479757   BANK OF AMERICA, NATIONAL ASSOCIATION    OH    43318
# 5479758                    JPMORGAN CHASE & CO.    FL    33436
# 5479759        BANKUNITED, NATIONAL ASSOCIATION    FL    34280
# 5479760                  Prospect Mortgage, LLC    NY    11433
# 5479761                           DISCOVER BANK    CO    80012
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 0             Consent not provided           Web           2024-06-19
# 1             Consent not provided           Web           2024-06-19
# 2             Consent not provided           Web           2024-06-19
# 3             Consent not provided           Web           2024-06-19
# 4             Consent not provided           Web           2024-06-16
# ...                            ...           ...                  ...
# 5479757       Consent not provided           Web           2013-06-05
# 5479758       Consent not provided      Referral           2011-12-30
# 5479759       Consent not provided      Referral           2013-04-23
# 5479760       Consent not provided           Web           2013-03-05
# 5479761       Consent not provided           Web           2012-05-01
#
#         Company response to consumer Timely response?  Complaint ID
# 0                        In progress              Yes       9293753
# 1                        In progress              Yes       9285953
# 2                        In progress              Yes       9286007
# 3                        In progress              Yes       9286153
# 4            Closed with explanation              Yes       9269708
# ...                              ...              ...           ...
# 5479757      Closed with explanation              Yes        424184
# 5479758        Closed without relief               No         69708
# 5479759      Closed with explanation              Yes        390852
# 5479760      Closed with explanation              Yes        341832
# 5479761        Closed without relief              Yes         68298
#
# [5479762 rows x 14 columns]

# %% [markdown]
# # Visualize the Target Feature(Coustomer Disputed)

# %%
percentage=df['']
